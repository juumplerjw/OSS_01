# %% [markdown]
# <a href="https://colab.research.google.com/github/juumplerjw/OSS_01/blob/main/WEEK10_OSS_%EA%B9%80%EC%A0%95%EC%9A%B0_20232018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
class Gizmo:
    def __init__(self):
        print('Gizmo id: %d' % id(self))

x = Gizmo()
# Out:
# Gizmo id: 134831866981712

# %%
y = Gizmo()
# Out:
# Gizmo id: 134832388681664

# %%
dir()
# Out:
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x',
#  'y']

# %%
charles = {'name': 'Charles L. Dodgson', 'born': 1832}
lewis = charles
lewis is charles
# Out:
# True

# %%
id(charles), id(lewis)
# Out:
# (134831861369152, 134831861369152)

# %%
lewis['balance'] = 950
charles
# Out:
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %%
alex = {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}
alex == charles
# Out:
# True

# %%
alex is charles
# Out:
# False

# %%
t1 = (1,2,[30,40])
t2 = (1,2,[30,40])
t1 == t2, t1 is t2
# Out:
# (True, False)

# %%
id(t1[-1])
# Out:
# 134831861367296

# %%
t1[-1].append(99)
t1, id(t1[-1])
# Out:
# ((1, 2, [30, 40, 99]), 134831861367296)

# %%
t1 == t2
# Out:
# False

# %%
l1 = [3, [55, 44], (7, 8, 9)]
l2 = list(l1)
l2
# Out:
# [3, [55, 44], (7, 8, 9)]

# %%
l2 == l1
# Out:
# True

# %%
l2 is l1
# Out:
# False

# %%
l1 = [3, [66,55,44], (7,8,9)]
l2 = list(l1)

# %%
l1.append(100)

# %%
l1[1].remove(55)
print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]

# %%
l2[1] += [33,22]

# %%
l2[2] += (10,11)

print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
class Bus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)
    def pick(self, name):
        self.passengers.append(name)
    def drop(self, name):
        self.passengers.remove(name)

# %%
import copy
bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)
id(bus1), id(bus2), id(bus3)
# Out:
# (134831864773088, 134831864792896, 134831864807056)

# %%
import copy
bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)

bus1.drop('Bill')
bus1.passengers, bus2.passengers, bus3.passengers
# Out:
# (['Alice', 'Claire', 'David'],
#  ['Alice', 'Claire', 'David'],
#  ['Alice', 'Bill', 'Claire', 'David'])

# %%
id(bus1.passengers), id(bus2.passengers), id(bus3.passengers)
# Out:
# (134831861765696, 134831861765696, 134831857233856)

# %%
a = [10, 20]
b = [a, 30]
a.append(b)
a
# Out:
# [10, 20, [[...], 30]]

# %%
c = copy.deepcopy(a)
c
# Out:
# [10, 20, [[...], 30]]

# %%
def f(a,b):
    a += b
    return a

# %%
a = [1,2]
b = [3,4]
f(a,b), (a, b)
# Out:
# ([1, 2, 3, 4], ([1, 2, 3, 4], [3, 4]))

# %%
x = 1
y =2
f(x,y), (x, y)
# Out:
# (3, (1, 2))

# %%
t = (10,20)
u = (30,40)
f(t,u), (t, u)
# Out:
# ((10, 20, 30, 40), ((10, 20), (30, 40)))

# %%
class HauntedBus:
    """A bus model haunted by ghost passengers"""
    def __init__(self, passengers=[]):
        self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
bus1 = HauntedBus(['Alice', 'Bill'])
bus1.passengers
# Out:
# ['Alice', 'Bill']

# %%
bus1.pick('Charlie')
bus1.drop('Alice')
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
bus2 = HauntedBus()
bus2.pick('Carrie')
bus2.passengers
# Out:
# ['Carrie']

# %%
bus3 = HauntedBus()
bus3.passengers
# Out:
# ['Carrie']

# %%
bus3.pick('Dave')
bus2.passengers
# Out:
# ['Carrie', 'Dave']

# %%
bus2.passengers is bus3.passengers
# Out:
# True

# %%
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
HauntedBus.__init__.__defaults__
# Out:
# (['Carrie', 'Dave'],)

# %%
HauntedBus.__init__.__defaults__[0] is bus2.passengers
# Out:
# True

# %%
class TwilightBus:
    """A bus model that makes passengers vanish"""
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Maya', 'Diana']

# %%
class TwilightBus:
    """A bus model that makes passengers vanish"""
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %%
import weakref
s1 = {1,2,3}
s2 = s1
def bye():
    print('Gone with the wind...')
ender = weakref.finalize(s1, bye)
ender.alive
# Out:
# True

# %%
del s1
ender.alive
# Out:
# True

# %%
s2 = 'spam'
# Out:
# Gone with the wind...

# %%
ender.alive
# Out:
# False
